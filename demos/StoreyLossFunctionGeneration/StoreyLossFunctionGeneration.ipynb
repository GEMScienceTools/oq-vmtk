# %% [markdown]
# # Generating and Visualizing Storey Loss Functions
#
# ## Overview
#
# This Jupyter Notebook outlines the workflow for reading inventory files that contain a list of typical nonstructural components along with their related metrics, such as quantities, demand-based fragility function parameters, and associated costs.
#
# The required input files, in comma-separated values format, are structured as follows:
# 1. **Component ID**: Component Identifier (must be a unique positive integer -- need not be sequential)
# 2. **Description**: Component description
# 3. **EDP**: Engineering Demand Parameter. Supported options are 'PSD' and 'PFA'
# 4. **Typology**: Type of component. Options include 'S' for structural and 'NS' for nonstructural
# 5. **Performance Group**: Useful for aggregating storey loss functions when the "do_grouping" argument is set to True in the slf_generator
# 6. **Quantity**: Number of components
# 7. **Damage States**: Number of possible damage states
# 8. **DSx, Median**: Median seismic demand (PSD or PFA) for damage state x of component y
# 9. **DSx, Total Dispersion**: Total uncertainty associated with the demand
# 10. **DSx, Cost**: Repair cost for damage state x of component y
# 11. **DSx, Cost Dispersion**: Dispersion in repair costs
# 12. **DSx, Best Fit**: Distribution type for damage state x. Options include 'Normal' or 'Lognormal', with 'Normal' as the default
#
# The main goals of this notebook:
#
# 1. **Load Component Inventory Files**: Read in component damage inventory files. The files should adhere to the structure provided in the example to ensure they are easily parsed and processed.
# 2. **Generate Storey Loss Functions**: Use the "slfgenerator" class from oq-vmtk to sample damage states and repair costs via Monte Carlo simulation and summarise them as the empirical 16th/50th (median)/84th percentile of the storey loss ratio vs. EDP -- no parametric curve is fitted.
# 3. **Model Correlated Damage**: Optionally couple the damage state of one component to another via a `correlation_tree`, so that damaging one component (e.g. a partition wall) forces a minimum damage state on another (e.g. the door framed into it).
# 4. **Visualize Storey Loss Functions**: Use the "plotter" class from oq-vmtk to visualize the results generated by the "slfgenerator" class.
#
# The notebook works through two examples side by side, for both drift- and acceleration-sensitive components:
#
# - **Example A -- Independent components**: components are damaged independently of one another (no `correlation_tree`).
# - **Example B -- Correlated components**: the same inventories, with a `correlation_tree` coupling interior doors to the partition walls they're framed into (drift-sensitive), and HVAC diffusers / in-ceiling sprinkler drops to the suspended-ceiling grid they're fixed to (acceleration-sensitive).
#
# This notebook provides a step-by-step guide on how to process storey loss functions efficiently, extract key performance metrics, and present the data in an understandable format. A basic understanding of earthquake engineering and data processing is recommended to make full use of the content in this notebook.
#
# ## Acknowledgements
#
# This example and the source code of the slfgenerator module are built upon the original work by Dr. Davit Shahnazaryan and Prof. Gerard O'Reilly, whose contributions to the field have been invaluable. We would like to acknowledge and express our appreciation for Dr. Shahnazaryan’s and Prof. O'Reilly efforts in this area.
#
#
# ## References
#
# [1] Shahnazaryan D, O’Reilly GJ, Monteiro R. Story loss functions for seismic design and assessment: Development of tools and application. Earthquake Spectra 2021; 37(4): 2813–2839. DOI: 10.1177/87552930211023523.
#
# [2] Shahnazaryan D, O’Reilly GJ, Monteiro R. Development of a Python-Based Storey Loss Function Generator. COMPDYN 2021 - 8th International Conference on Computational Methods in Structural Dynamics and Earthquake Engineering, 2021. DOI: 10.7712/120121.8659.18567.
#
# [3] O’Reilly, G. J., & Shahnazaryan, D. (2024). On the utility of story loss functions for regional seismic vulnerability modeling and risk assessment. Earthquake Spectra, 40(3), 1933–1955. https://doi.org/10.1177/87552930241245940

# %% [markdown]
# ## Import Libraries ##

# %%
import os
import numpy as np
import pandas as pd

# Import the classes necessary for generating and visualising storey loss functions
from openquake.vmtk.plotter import plotter
from openquake.vmtk.utilities import export_to_pkl
from openquake.vmtk.slfgenerator import slfgenerator

# %% [markdown]
# ## Load Components Inventory ##

# %%
# The set of drift- and acceleration-sensitive inventory of nonstructural components are compatible
# with the FEMA P-58 database and were obtained using the "Normative Quantity Estimation Tool"
# (https://femap58.atcouncil.org/supporting-materials) assuming a residential occupancy class

inventory_directory = './in'

# Load the inventory of drift-sensitive components
inventory_psd = pd.read_csv(os.path.join(inventory_directory, 'inventory_psd.csv'))

# Print the drift-sensitive components csv contents
print(inventory_psd.head(5))

# Load the inventory of acceleration-sensitive components
inventory_pfa = pd.read_csv(os.path.join(inventory_directory, 'inventory_pfa.csv'))

# Print the acceleration-sensitive components csv contents
print(inventory_pfa.head(5))
# Out:
#    Component ID                        Description  EDP Typology  \
# 0             1         Cladding - Gross Wall Area  PSD       NS
# 1             2  Cladding - Windows & Glazing Area  PSD       NS
# 2             3                              Doors  PSD       NS
# 3             4                            Windows  PSD       NS
# 4             5                  Gypsum Partitions  PSD       NS
#
#    Performance Group  Quantity  Damage States  DS1, Median  DS2, Median  \
# 0                  1  0.071535              2       0.0338       0.0383
# 1                  1  0.013935              2       0.0338       0.0383
# 2                  1  0.150000              1       0.0188          NaN
# 3                  1  0.220000              1       0.0188          NaN
# 4                  1  0.210000              4       0.0018       0.0046
#
#    DS3, Median  ...  DS1, Cost Dispersion  DS2, Cost Dispersion  \
# 0          NaN  ...                0.1700                0.1700
# ...

# %% [markdown]
# ## Define Storey Loss Function Generator Inputs ##

# %%
# Number of damage realizations per EDP range
rlz = 500

# Engineering demand parameter range
psd_range = np.linspace(0.001, 0.1, 100)  # interstorey drift in rad
pfa_range = np.linspace(0.001, 5.0, 100)  # peak floor acceleration in g

# Replacement cost value
repCost = 1.0

# Currency conversion rate. Useful if the inventory costs are in a foreign
# currency and need to be converted to the local market currency.
conversion_rate = 1.0

# Performance grouping flag. Set to True to aggregate sub-component SLFs
# into a single performance group (e.g., for drift-sensitive components).
grouping_flag = True

# %% [markdown]
# ## Load Correlation Trees for Example B ##
#
# Correlation rules (mirroring the production nonstructural SLF pipeline this demo is based on):
# - **PSD**: interior door assemblies are framed into the partition wall's studs -- once the partition passes cosmetic cracking (DS &ge; 2), the door frame racks along with it, forced to at least its own DS1. `correlation_tree_psd.csv` couples component 3 (Doors) to component 5 (Gypsum Partitions).
# - **PFA**: suspended-ceiling grid failure (DS &ge; 2) drags down whatever is fixed to the grid -- HVAC diffusers and in-ceiling sprinkler drops -- forcing them to at least their own DS1. `correlation_tree_pfa.csv` couples components 12 (HVAC in-line Drops & Diffusers) and 20 (Sprinkler Drops) to component 3 (Ceilings - Gypsum board -- the dominant ceiling type by quantity, vs. component 4 "Ceilings - Other").
#
# Each correlation tree is a plain CSV alongside the inventory it applies to, in the same `slfgenerator` schema as the inventory files: one row per `Component ID`, a `DEPENDENT ON ITEM` column ("Independent" or the causation component's ID), and one `DSk` column per possible damage state of the causation component giving the minimum damage state forced on the dependent component once the causation component reaches DSk.

# %%
correlation_tree_psd = pd.read_csv(os.path.join(inventory_directory, 'correlation_tree_psd.csv'))
correlation_tree_pfa = pd.read_csv(os.path.join(inventory_directory, 'correlation_tree_pfa.csv'))

print(correlation_tree_psd)
print(correlation_tree_pfa[['ID', 'DEPENDENT ON ITEM', 'DS0', 'DS1', 'DS2', 'DS3', 'DS4']])
# Out:
#    ID DEPENDENT ON ITEM          DS0          DS1          DS2          DS3  \
# 0   1       Independent  Independent  Independent  Independent  Independent
# 1   2       Independent  Independent  Independent  Independent  Independent
# 2   3                 5  Independent  Independent          DS1          DS1
# 3   4       Independent  Independent  Independent  Independent  Independent
# 4   5       Independent  Independent  Independent  Independent  Independent
# 5   6       Independent  Independent  Independent  Independent  Independent
# 6   7       Independent  Independent  Independent  Independent  Independent
#
#            DS4
# 0  Independent
# 1  Independent
# 2          DS1
# 3  Independent
# 4  Independent
# 5  Independent
# 6  Independent
#     ID DEPENDENT ON ITEM          DS0          DS1          DS2          DS3  \
# 0    1       Independent  Independent  Independent  Independent  Independent
# ...

# %% [markdown]
# ## Example A — Independent Components ##
#
# No `correlation_tree` is passed; components are assumed to be damaged independently of one another.

# %% [markdown]
# ### Drift-Sensitive Components ###

# %%
# Initialise the slfgenerator class -- no correlation_tree
psd_model_a = slfgenerator(inventory_psd,
                           edp='PSD',
                           edp_range=psd_range,
                           grouping_flag=grouping_flag,
                           conversion=conversion_rate,
                           realizations=rlz,
                           replacement_cost=repCost)

# Generate the SLFs using the "generate()" method. "out_a_psd" contains,
# per performance group, the empirical 16th/50th (median)/84th percentile
# of the storey loss ratio vs. EDP -- no parametric curve is fitted.
out_a_psd, cache_a_psd = psd_model_a.generate()
export_to_pkl('./out/slf_drift_A.pkl', out_a_psd)

# %%
# Visualise the drift-sensitive nonstructural components storey loss
# function using the "plot_slf_model" method from the plotter class

# Initialise the plotter class
pl = plotter()

pl.plot_slf_model(out_a_psd,
                  cache_a_psd,
                  edp_label='Interstorey Drift Ratio [-]',
                  loss_label='Drift-Sensitive NSC Storey Loss Ratio',
                  xlims=[0, 0.05],
                  ylims=None,
                  title='Drift-Sensitive SLF — Example A (Independent)',
                  export_path='./out/drift_slf_A.png')

# %% [markdown]
# ### Acceleration-Sensitive Components ###

# %%
# Initialise the slfgenerator class -- no correlation_tree
pfa_model_a = slfgenerator(inventory_pfa,
                           edp='PFA',
                           edp_range=pfa_range,
                           grouping_flag=grouping_flag,
                           conversion=conversion_rate,
                           realizations=rlz,
                           replacement_cost=repCost)

out_a_pfa, cache_a_pfa = pfa_model_a.generate()
export_to_pkl('./out/slf_accel_A.pkl', out_a_pfa)

# %%
pl.plot_slf_model(out_a_pfa,
                  cache_a_pfa,
                  edp_label='Peak Floor Acceleration [g]',
                  loss_label='Acceleration-Sensitive NSC Storey Loss Ratio',
                  xlims=[0, 5],
                  ylims=None,
                  title='Acceleration-Sensitive SLF — Example A (Independent)',
                  export_path='./out/accel_slf_A.png')

# %% [markdown]
# ## Example B — Correlated Components ##
#
# The same two inventories and parameters as Example A, with the correlation trees loaded above coupling doors to partitions (drift-sensitive) and HVAC diffusers/sprinkler drops to ceilings (acceleration-sensitive).
#
# The two correlations have a different aggregate effect on this particular inventory, and that difference is itself informative:
#
# - **Drift-sensitive**: doors (component 3) are physically framed into the partition wall (component 5) and have a *higher* fragility threshold than the correlation's DS2 trigger, so once the partition is sufficiently damaged the door is very often forced into damage it would not yet have reached on its own -- the correlation materially raises the group's median loss ratio.
# - **Acceleration-sensitive**: HVAC diffusers and sprinkler drops (components 12, 20) already have *lower* independent fragility thresholds than the ceiling's DS2 trigger (1.3 g and 0.75-0.95 g vs. 1.58 g) -- by the acceleration level where the ceiling is likely to have reached DS2, these components are usually already independently damaged, so forcing a minimum DS1 changes little at the aggregate group level, even though the dependency is real and does bind in individual Monte Carlo realizations.
#
# Both are the physically correct correlation for this inventory (mirroring the real production rule this demo is based on) -- the small aggregate PFA effect is a genuine finding about *this* occupancy's component fragilities, not a limitation of the correlation-tree mechanism.

# %% [markdown]
# ### Drift-Sensitive Components ###

# %%
psd_model_b = slfgenerator(inventory_psd,
                           edp='PSD',
                           edp_range=psd_range,
                           correlation_tree=correlation_tree_psd,
                           grouping_flag=grouping_flag,
                           conversion=conversion_rate,
                           realizations=rlz,
                           replacement_cost=repCost)

out_b_psd, cache_b_psd = psd_model_b.generate()
export_to_pkl('./out/slf_drift_B.pkl', out_b_psd)

# %%
pl.plot_slf_model(out_b_psd,
                  cache_b_psd,
                  edp_label='Interstorey Drift Ratio [-]',
                  loss_label='Drift-Sensitive NSC Storey Loss Ratio',
                  xlims=[0, 0.05],
                  ylims=None,
                  title='Drift-Sensitive SLF — Example B (Correlated)',
                  export_path='./out/drift_slf_B.png')

# %% [markdown]
# ### Acceleration-Sensitive Components ###

# %%
pfa_model_b = slfgenerator(inventory_pfa,
                           edp='PFA',
                           edp_range=pfa_range,
                           correlation_tree=correlation_tree_pfa,
                           grouping_flag=grouping_flag,
                           conversion=conversion_rate,
                           realizations=rlz,
                           replacement_cost=repCost)

out_b_pfa, cache_b_pfa = pfa_model_b.generate()
export_to_pkl('./out/slf_accel_B.pkl', out_b_pfa)

# %%
pl.plot_slf_model(out_b_pfa,
                  cache_b_pfa,
                  edp_label='Peak Floor Acceleration [g]',
                  loss_label='Acceleration-Sensitive NSC Storey Loss Ratio',
                  xlims=[0, 5],
                  ylims=None,
                  title='Acceleration-Sensitive SLF — Example B (Correlated)',
                  export_path='./out/accel_slf_B.png')

# %% [markdown]
# ## Compare Example A vs. Example B ##
#
# Overlaying both examples on the same axes (via `plot_slf_model`'s multi-key support) makes the effect of each correlation tree directly visible. For the drift-sensitive group, Example B's median loss ratio sits visibly above Example A's once the partition is damaged enough to start forcing the door; for the acceleration-sensitive group, the two curves largely overlap, for the physical reason discussed above -- a useful reminder that a correlation tree changes results only where the dependent component's own fragility genuinely trails its causation component's.

# %%
group_psd = next(iter(out_a_psd))   # 'PSD, NS'
group_pfa = next(iter(out_a_pfa))   # 'PFA, NS'

pl.plot_slf_model(
    {'Example A': out_a_psd[group_psd], 'Example B': out_b_psd[group_psd]},
    {'Example A': cache_a_psd[group_psd], 'Example B': cache_b_psd[group_psd]},
    edp_label='Interstorey Drift Ratio [-]',
    loss_label='Drift-Sensitive NSC Storey Loss Ratio',
    xlims=[0, 0.05], ylims=None,
    title='Drift-Sensitive SLF — Example A vs. Example B',
    export_path='./out/drift_slf_A_vs_B.png')

pl.plot_slf_model(
    {'Example A': out_a_pfa[group_pfa], 'Example B': out_b_pfa[group_pfa]},
    {'Example A': cache_a_pfa[group_pfa], 'Example B': cache_b_pfa[group_pfa]},
    edp_label='Peak Floor Acceleration [g]',
    loss_label='Acceleration-Sensitive NSC Storey Loss Ratio',
    xlims=[0, 5], ylims=None,
    title='Acceleration-Sensitive SLF — Example A vs. Example B',
    export_path='./out/accel_slf_A_vs_B.png')
